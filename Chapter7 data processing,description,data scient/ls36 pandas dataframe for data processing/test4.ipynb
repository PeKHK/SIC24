# %%
#coberting excel to dataframe
'''
df=pd.read_excel("file.xls",sheet_name=0,header=0)
df.head()
'''

# %%
#convert json to dataframe
'''
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_json('file.json',orient='records')
df.head()
'''

# %%
#reading data from remote data service using datareader api
import matplotlib.pyplot as plt
import pandas_datareader as pdr
df=pdr.get_data_fred('GS10')
plt.plot(df)
plt.show()
